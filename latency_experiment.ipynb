# %%
# --- Installation (Run in a Colab code cell) ---
# %pip install -U transformers datasets pandas scipy sentence-transformers
# Note: ColModernVBERT requires custom code/processor from the colpali library
# !git clone https://github.com/illuin-tech/colpali.git
# !cd colpali && git checkout vbert && pip install -e .
# Out:
# Requirement already satisfied: transformers in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (4.57.3)
# Requirement already satisfied: datasets in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (4.4.1)
# Requirement already satisfied: pandas in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: scipy in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (1.16.3)
# Requirement already satisfied: sentence-transformers in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (5.1.2)
# Requirement already satisfied: filelock in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: httpx<1.0.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (4.12.0)
# Requirement already satisfied: certifi in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: torch>=1.11.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from sentence-transformers) (2.8.0)
# Requirement already satisfied: scikit-learn in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: Pillow in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from sentence-transformers) (12.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: setuptools in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.6)
# Requirement already satisfied: jinja2 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Cloning into 'colpali'...
# remote: Enumerating objects: 3822, done.
# remote: Counting objects: 100% (1291/1291), done.
# remote: Compressing objects: 100% (364/364), done.
# remote: Total 3822 (delta 1125), reused 927 (delta 927), pack-reused 2531 (from 2)
# Receiving objects: 100% (3822/3822), 867.78 KiB | 7.42 MiB/s, done.
# Resolving deltas: 100% (2422/2422), done.
# branch 'vbert' set up to track 'origin/vbert'.
# Switched to a new branch 'vbert'
# Obtaining file:///Users/sjoerdgunneweg/Documents/MSc_AI/IR2/modernvbert/colpali/colpali/colpali/colpali
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from colpali_engine==0.3.13.dev52+geb561da6d) (2.3.5)
# Requirement already satisfied: peft<0.18.0,>=0.14.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from colpali_engine==0.3.13.dev52+geb561da6d) (0.17.1)
# Requirement already satisfied: pillow>=10.0.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from colpali_engine==0.3.13.dev52+geb561da6d) (12.0.0)
# Requirement already satisfied: requests in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from colpali_engine==0.3.13.dev52+geb561da6d) (2.32.5)
# Requirement already satisfied: scipy in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from colpali_engine==0.3.13.dev52+geb561da6d) (1.16.3)
# Requirement already satisfied: torch<2.9.0,>=2.2.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from colpali_engine==0.3.13.dev52+geb561da6d) (2.8.0)
# Requirement already satisfied: torchvision in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from colpali_engine==0.3.13.dev52+geb561da6d) (0.23.0)
# Requirement already satisfied: transformers<4.58.0,>=4.53.1 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from colpali_engine==0.3.13.dev52+geb561da6d) (4.57.3)
# Requirement already satisfied: packaging>=20.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from peft<0.18.0,>=0.14.0->colpali_engine==0.3.13.dev52+geb561da6d) (25.0)
# Requirement already satisfied: psutil in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from peft<0.18.0,>=0.14.0->colpali_engine==0.3.13.dev52+geb561da6d) (7.1.3)
# Requirement already satisfied: pyyaml in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from peft<0.18.0,>=0.14.0->colpali_engine==0.3.13.dev52+geb561da6d) (6.0.3)
# Requirement already satisfied: tqdm in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from peft<0.18.0,>=0.14.0->colpali_engine==0.3.13.dev52+geb561da6d) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from peft<0.18.0,>=0.14.0->colpali_engine==0.3.13.dev52+geb561da6d) (1.12.0)
# Requirement already satisfied: safetensors in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from peft<0.18.0,>=0.14.0->colpali_engine==0.3.13.dev52+geb561da6d) (0.7.0)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from peft<0.18.0,>=0.14.0->colpali_engine==0.3.13.dev52+geb561da6d) (0.36.0)
# Requirement already satisfied: filelock in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from torch<2.9.0,>=2.2.0->colpali_engine==0.3.13.dev52+geb561da6d) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from torch<2.9.0,>=2.2.0->colpali_engine==0.3.13.dev52+geb561da6d) (4.15.0)
# Requirement already satisfied: setuptools in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from torch<2.9.0,>=2.2.0->colpali_engine==0.3.13.dev52+geb561da6d) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from torch<2.9.0,>=2.2.0->colpali_engine==0.3.13.dev52+geb561da6d) (1.14.0)
# Requirement already satisfied: networkx in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from torch<2.9.0,>=2.2.0->colpali_engine==0.3.13.dev52+geb561da6d) (3.6)
# Requirement already satisfied: jinja2 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from torch<2.9.0,>=2.2.0->colpali_engine==0.3.13.dev52+geb561da6d) (3.1.6)
# Requirement already satisfied: fsspec in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from torch<2.9.0,>=2.2.0->colpali_engine==0.3.13.dev52+geb561da6d) (2025.10.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from transformers<4.58.0,>=4.53.1->colpali_engine==0.3.13.dev52+geb561da6d) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from transformers<4.58.0,>=4.53.1->colpali_engine==0.3.13.dev52+geb561da6d) (0.22.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft<0.18.0,>=0.14.0->colpali_engine==0.3.13.dev52+geb561da6d) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from sympy>=1.13.3->torch<2.9.0,>=2.2.0->colpali_engine==0.3.13.dev52+geb561da6d) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from jinja2->torch<2.9.0,>=2.2.0->colpali_engine==0.3.13.dev52+geb561da6d) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from requests->colpali_engine==0.3.13.dev52+geb561da6d) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from requests->colpali_engine==0.3.13.dev52+geb561da6d) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from requests->colpali_engine==0.3.13.dev52+geb561da6d) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sjoerdgunneweg/miniconda3/envs/latency_experiment/lib/python3.12/site-packages (from requests->colpali_engine==0.3.13.dev52+geb561da6d) (2025.11.12)
# Building wheels for collected packages: colpali_engine
#   Building editable for colpali_engine (pyproject.toml) ... done
#   Created wheel for colpali_engine: filename=colpali_engine-0.3.13.dev52+geb561da6d-py3-none-any.whl size=11619 sha256=2b091ebcf36cd686542b81e08862f0a2d4db8256d0de9eb03b2b2cd476055ed4
#   Stored in directory: /private/var/folders/9n/p0bhn0y10r16h85vsfzm0zqc0000gn/T/pip-ephem-wheel-cache-g1sr59r4/wheels/4b/05/cc/66a9a6bd5cf01da1daacad932fc30b453fad78a068f32704eb
# Successfully built colpali_engine
# Installing collected packages: colpali_engine
#   Attempting uninstall: colpali_engine
#     Found existing installation: colpali_engine 0.3.13.dev52+geb561da6d
#     Uninstalling colpali_engine-0.3.13.dev52+geb561da6d:
#       Successfully uninstalled colpali_engine-0.3.13.dev52+geb561da6d
# Successfully installed colpali_engine-0.3.13.dev52+geb561da6d

# %%
# %%capture
# !git clone https://github.com/illuin-tech/colpali.git
# %cd colpali
# %pip install -e .

# %%
import torch
import time
import numpy as np
from colpali_engine.models import ColModernVBert, ColModernVBertProcessor
from typing import List
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 5
#       3 import numpy as np
#       4 import os
# ----> 5 from colpali_engine.models import ColModernVBert, ColModernVBertProcessor
#       6 from typing import List
#
# File ~/Documents/MSc_AI/IR2/modernvbert/colpali/colpali/colpali/colpali/colpali_engine/__init__.py:1
# ----> 1 from .models import (
#       2     BiModernVBert,
#       3     BiModernVBertProcessor,
#       4     BiPali,
#       5     BiPaliProj,
#       6     BiQwen2,
#       7     BiQwen2_5,
#       8     BiQwen2_5_Processor,
#       9     BiQwen2Processor,
#      10     ColIdefics3,
#      11     ColIdefics3Processor,
#      12     ColModernVBert,
#      13     ColModernVBertProcessor,
#      14     ColPali,
#      15     ColPaliProcessor,
#      16     ColQwen2,
#      17     ColQwen2_5,
#      18     ColQwen2_5_Processor,
#      19     # ColQwen2_5Omni,
#      20     # ColQwen2_5OmniProcessor,
#      21     ColQwen2Processor,
#      22 )
#
# File ~/Documents/MSc_AI/IR2/modernvbert/colpali/colpali/colpali/colpali/colpali_engine/models/__init__.py:1
# ----> 1 from .idefics3 import BiIdefics3, BiIdefics3Processor, ColIdefics3, ColIdefics3Processor
#       2 from .modernvbert import BiModernVBert, BiModernVBertProcessor, ColModernVBert, ColModernVBertProcessor
#       3 from .paligemma import BiPali, BiPaliProcessor, BiPaliProj, ColPali, ColPaliProcessor
#
# File ~/Documents/MSc_AI/IR2/modernvbert/colpali/colpali/colpali/colpali/colpali_engine/models/idefics3/__init__.py:1
# ----> 1 from .biidefics3 import BiIdefics3, BiIdefics3Processor
#       2 from .colidefics3 import ColIdefics3, ColIdefics3Processor
#
# File ~/Documents/MSc_AI/IR2/modernvbert/colpali/colpali/colpali/colpali/colpali_engine/models/idefics3/biidefics3/__init__.py:1
# ----> 1 from .modeling_biidefics3 import BiIdefics3
#       2 from .processing_biidefics3 import BiIdefics3Processor
#
# File ~/Documents/MSc_AI/IR2/modernvbert/colpali/colpali/colpali/colpali/colpali_engine/models/idefics3/biidefics3/modeling_biidefics3.py:4
#       1 from typing import Literal
#       3 import torch
# ----> 4 from transformers import Idefics3Config, Idefics3Model, Idefics3PreTrainedModel
#       7 class BiIdefics3(Idefics3PreTrainedModel):
#       8     """
#       9     Initializes the BiIdefics3 model.
#      10
#      11     Args:
#      12         config : The model configuration.
#      13     """
#
# ModuleNotFoundError: No module named 'transformers'

# %%
def load_queries_from_csv(file_path: str, query_column: str) -> List[str]:
    df = pd.read_csv(file_path)
    return df[query_column].tolist()

queries = load_queries_from_csv('/content/sampled_queries.csv', 'query')

# %%
device = torch.device("cpu")

def measure_latency_modernvbert(queries: List[str], model_id: str) -> float:
    """Loads the model, encodes the queries, and measures average latency."""
    
    print(f" Loading {model_id} onto {device}")
    
    processor = ColModernVBertProcessor.from_pretrained(model_id)
    # Use float32 for CPU compatibility, or torch_dtype=torch.float16 if supported for speed
    model = ColModernVBert.from_pretrained(model_id, dtype=torch.float32, trust_remote_code=True).to(device).eval()
    
    print("Warm-up Run (10 queries)")
    warmup_queries = queries[:10]
    
    with torch.no_grad():
        warmup_inputs = processor.process_texts(warmup_queries).to(device)
        _ = model(**warmup_inputs)
    
    print(f"--- Timing {len(queries)} Queries on CPU ---")
    
    start_time = time.time()
    for query in queries:
        with torch.no_grad():
            inputs = processor.process_texts([query]).to(device)
            _ = model(**inputs) 
            
    end_time = time.time()
    
    total_time = end_time - start_time
    avg_latency = total_time / len(queries)
    
    print("\n Latency Results")
    print(f"Total time for {len(queries)} queries: {total_time:.3f} seconds")
    print(f"Average Query Encoding Latency: {avg_latency:.3f} seconds/query")
    print(f"Paper's Reported Latency: 0.032 seconds/query")
    print("----------------------------")
    
    return avg_latency
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 7
#       3 # os.environ["OMP_NUM_THREADS"] = "1"
#       4 # os.environ["MKL_NUM_THREADS"] = "1"
#       5 device = torch.device("cpu")
# ----> 7 def measure_latency(queries: List[str], model_id: str):
#       8     """Loads the model, encodes the queries, and measures average latency."""
#      10     # --- 1. Load Model and Processor ---
#
# NameError: name 'List' is not defined

# %%
from colpali_engine.models import ColQwen2_5, ColQwen2_5_Processor
def measure_latency_colqwen(queries: List[str], model_id: str) -> float:

    """Loads the model, encodes the queries, and measures average latency."""
    
    print(f" Loading {model_id} onto {device}")
    
    processor = ColQwen2_5_Processor.from_pretrained(model_id, dtype=torch.float32, trust_remote_code=True)
    # Use float32 for CPU compatibility, or torch_dtype=torch.float16 if supported for speed
    model = ColQwen2_5.from_pretrained(model_id, dtype=torch.bfloat16).to(device).eval()
    
    print("Warm-up Run (10 queries)")
    warmup_queries = queries[:10]
    
    with torch.no_grad():
        warmup_inputs = processor.process_texts(warmup_queries).to(device)
        _ = model(**warmup_inputs)
    
    print(f"--- Timing {len(queries)} Queries on CPU ---")
    
    start_time = time.time()
    inputs = processor.process_texts(queries).to(device)
    with torch.no_grad():
        _ = model(**inputs) 
            
    end_time = time.time()
    
    total_time = end_time - start_time
    avg_latency = total_time / len(queries)
    
    print("\n Latency Results")
    print(f"Total time for {len(queries)} queries: {total_time:.3f} seconds")
    print(f"Average Query Encoding Latency: {avg_latency:.3f} seconds/query")
    print(f"Paper's Reported Latency: 0.032 seconds/query")
    print("----------------------------")
    
    return avg_latency

# %%
import torch
from torch.utils.data import DataLoader
from transformers import AutoProcessor
from PIL import Image

from colpali_engine.models import ColPali, ColPaliProcessor

def measure_latency_colpali(queries: List[str], model_id: str) -> float:

    """Loads the model, encodes the queries, and measures average latency."""
    
    print(f" Loading {model_id} onto {device}")
    
    processor = AutoProcessor.from_pretrained(model_id)
    # Use float32 for CPU compatibility, or torch_dtype=torch.float16 if supported for speed
    model = ColPali.from_pretrained(model_id, dtype=torch.bfloat16).to_device(device).eval()
    
    print("Warm-up Run (10 queries)")
    warmup_queries = queries[:10]
    
    warmup_batch_queries = processor.process_queries(warmup_queries).to(device)

    with torch.no_grad():
      query_embeddings = model(**warmup_batch_queries)
    
    print(f"--- Timing {len(queries)} Queries on CPU ---")
    
    start_time = time.time()
    
    batch_queries = processor.process_queries(queries).to(device)

    with torch.no_grad():
      query_embeddings = model(**batch_queries)
            
    end_time = time.time()
    
    total_time = end_time - start_time
    avg_latency = total_time / len(queries)
    
    print("\n Latency Results")
    print(f"Total time for {len(queries)} queries: {total_time:.3f} seconds")
    print(f"Average Query Encoding Latency: {avg_latency:.3f} seconds/query")
    print(f"Paper's Reported Latency: 0.032 seconds/query")
    print("----------------------------")
    
    return avg_latency

# %%
colmodernvbert_id = "ModernVBERT/colmodernvbert" #TODO flash attention gebruiken?
bi_modernvbert_id = "ModernVBERT/bimodernvbert"
colqwen2_5_id = "vidore/colqwen2-5-v0.2" #TODO maybe set to bfloat16 
colpali_id = "vidore/colpali-v1.1"


# --- Run Latency Measurement ---
avg_latency = measure_latency_modernvbert(queries, colmodernvbert_id)
print("ColModernVBERT Average Latency:", avg_latency)
avg_latency = measure_latency_modernvbert(queries, bi_modernvbert_id)
print("Bi-ModernVBERT Average Latency:", avg_latency)
avg_latency = measure_latency_colqwen(queries, colqwen2_5_id) 
print("ColQwen2-5 Average Latency:", avg_latency)
avg_latency = measure_latency_colpali(queries, colpali_id)
print("ColPali Average Latency:", avg_latency)
